# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

# %%
SSOCR_PATH = '../libs/ssocr'

# %%
img = cv2.VideoCapture('real_score_crop.png')

# %%
#img = cv2.VideoCapture('score1.png')
# Take each frame
#_, frame = img.read('score1.png')

img = cv2.imread('blimp.png')
img = cv2.medianBlur(img,5)
# Convert BGR to HSV
#hsv = cv2.cvtColor(frame, cv2.COLOR_RGB2HSV)

# define range of blue color in HSV
lower_blue = np.array([55,55,55])
upper_blue = np.array([130,255,255])

# Threshold the HSV image to get only blue colors
mask = cv2.inRange(img, lower_blue, upper_blue)

# Bitwise-AND mask and original image
res = cv2.bitwise_and(img,img, mask= mask)

ret2,thresh2 = cv2.threshold(res,130,255,0)

bw = cv2.cvtColor(thresh2, cv2.COLOR_RGB2HSV)

plt.figure()
plt.imshow(img)
plt.figure()
plt.imshow(mask)
plt.figure()
plt.imshow(res)
plt.figure()
plt.imshow(thresh2)
plt.figure()
plt.imshow(bw)

# %%
cv2.imwrite( "blue_num.png", bw)
# Out:
# True

# %%
import subprocess
print subprocess.check_output(SSOCR_PATH + ' -T -f white  -d -1 blue_num.png', shell=True)
# Out:
# 3

# %%
#img = cv2.VideoCapture('score1.png')
# Take each frame
#_, frame = img.read('score1.png')

img = cv2.imread('blimp2.png')
img = cv2.medianBlur(img,5)
# Convert BGR to HSV
#hsv = cv2.cvtColor(frame, cv2.COLOR_RGB2HSV)

# define range of blue color in HSV
lower_blue = np.array([50,50,50])
upper_blue = np.array([250,215,117])

# Threshold the HSV image to get only blue colors
mask = cv2.inRange(img, lower_blue, upper_blue)

# Bitwise-AND mask and original image
res = cv2.bitwise_and(img,img, mask= mask)

ret2,thresh2 = cv2.threshold(res,127,255,0)

bw = cv2.cvtColor(thresh2, cv2.COLOR_RGB2HSV)

plt.figure()
plt.imshow(img)
plt.figure()
plt.imshow(mask)
plt.figure()
plt.imshow(res)
plt.figure()
plt.imshow(thresh2)
plt.figure()
plt.imshow(bw)

# %%
cv2.imwrite( "orange_num.png", bw)
# Out:
# True

# %%
print subprocess.check_output(SSOCR_PATH + ' -T -f white -d -1 orange_num.png', shell=True)
# Out:
# 5
